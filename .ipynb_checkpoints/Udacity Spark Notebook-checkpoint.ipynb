# %%
import ibmos2spark
# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'service_id': 'iam-ServiceId-83c9fc3d-a029-4989-8bc5-6a0013958323',
    'iam_service_endpoint': 'https://iam.cloud.ibm.com/oidc/token',
    'api_key': 'n0G3snz0s4z1uLZXNLwgr2vTQziuMWQSjGNJMV6ACnR0'
}

configuration_name = 'os_fcadade136bb45d699bec52b7b8b350c_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

# import libraries
from pyspark.sql import SparkSession
from pyspark.ml.feature import RegexTokenizer, CountVectorizer, \
    IDF, StringIndexer
from pyspark.sql.functions import udf, asc, desc, countDistinct
from pyspark.sql.types import IntegerType
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Since JSON data can be semi-structured and contain additional metadata, it is possible that you might face issues with the DataFrame layout.
# Please read the documentation of 'SparkSession.read()' to learn more about the possibilities to adjust the data loading.
# PySpark documentation: http://spark.apache.org/docs/2.0.2/api/python/pyspark.sql.html#pyspark.sql.DataFrameReader.json

# df_data_1 = spark.read.json(cos.url('medium-sparkify-event-data.json', 'udacityspark-donotdelete-pr-5ai936sox18kwj'))
# df_data_1.take(5)
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20210123232625-0000
# KERNEL_ID = 2934b097-93e0-4afa-a304-155558d08895

# %%
# create a Spark session
spark = SparkSession.builder.appName('SparkifyEvents').getOrCreate()

# %%
df = spark.read.json(cos.url('medium-sparkify-event-data.json', 'udacityspark-donotdelete-pr-5ai936sox18kwj'))

# %%
#View the fields in the data frame
df.printSchema()

#Remove the 15,700 empty user ID's
df_filtered = df.where(df['userId'] != '')


#confirm that all records have at least one session Id
df_filtered.groupBy("sessionId").count().orderBy(asc("count")).show()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#
# +---------+-----+
# |sessionId|count|
# +---------+-----+
# |     2101|    1|
# |     2026|    1|
# |     2522|    1|
# |     4733|    1|
# |     1021|    1|
# |     2377|    1|
# |     2715|    1|
# |     1895|    1|
# |     1550|    1|
# |     1347|    1|
# |     2581|    1|
# |     1145|    1|
# |     4147|    1|
# |     2797|    1|
# |     3302|    1|
# |     1636|    1|
# |     1690|    1|
# |     1887|    1|
# |     3594|    1|
# |     3120|    1|
# +---------+-----+
# only showing top 20 rows

# %%
#free -vs- paid
#df.groupBy("level").count().orderBy("level").show()

#User events
events_page = df_filtered.groupBy("page").count().orderBy("page")
pandas_df = events_page.toPandas()
pandas_df = pandas_df.sort_values('count')

y_pos = np.arange(len(pandas_df['page']))
y_vals = pandas_df['count']


plt.barh(y_pos, y_vals, align='center', alpha=0.5)
plt.yticks(y_pos, pandas_df['page'])
plt.xlabel('Actions Count')
plt.ylabel('Actions Type')

plt.title('User Actions')

plt.show()

# %%
#Gender ratios
gender_df = df_filtered.groupBy("gender").count().orderBy("gender")
female_count = gender_df.where(gender_df['gender'] == 'F')
male_count = gender_df.where(gender_df['gender'] == 'M')
male_count_df = male_count.toPandas()
female_count_df = female_count.toPandas()

n_groups = 1
index = np.arange(n_groups)


rects1 = plt.bar(index, male_count_df['count'], 0.35,
alpha=0.8,
color='g',
label='Men')

rects2 = plt.bar(index + .35, female_count_df['count'], 0.35,
alpha=0.8,
color='r',
label='Women')

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender by Count')
plt.xticks(index + .35, ('', 'Men', 'Women'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

df_filtered_pandas = df_filtered.toPandas()


plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df_filtered_pandas.corr(), xticklabels=df_filtered_pandas.corr().columns, yticklabels=df_filtered_pandas.corr().columns, cmap='RdYlGn', center=0, annot=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
level_df = df_filtered.select("level", "page")
level_df_pandas = level_df.toPandas()

level_df_code = list(map(lambda x: int(1) if x == "free" else int(-1), level_df_pandas['level']))
level_df_pandas['code'] = level_df_code

# Plot
g = sns.catplot('level', col='page', col_wrap=4,
                data=level_df_pandas,
                kind="count", height=3.5, aspect=.8, 
                palette='tab20')

#fig.suptitle('sf')
plt.show()

'''plt.figure(figsize=(13,10), dpi= 80)
group_col = 'level'
order_of_bars = level_df_pandas.page.unique()[::-1]
colors = [plt.cm.Spectral(i/float(len(level_df_pandas[group_col].unique())-1)) for i in range(len(level_df_pandas[group_col].unique()))]

for c, group in zip(colors, level_df_pandas[group_col].unique()):
    sns.barplot(x='code', y='page', data=level_df_pandas.loc[level_df_pandas[group_col]==group, :], order=order_of_bars, color=c, label=group)
'''
# Out:
# "plt.figure(figsize=(13,10), dpi= 80)\ngroup_col = 'level'\norder_of_bars = level_df_pandas.page.unique()[::-1]\ncolors = [plt.cm.Spectral(i/float(len(level_df_pandas[group_col].unique())-1)) for i in range(len(level_df_pandas[group_col].unique()))]\n\nfor c, group in zip(colors, level_df_pandas[group_col].unique()):\n    sns.barplot(x='code', y='page', data=level_df_pandas.loc[level_df_pandas[group_col]==group, :], order=order_of_bars, color=c, label=group)\n"
